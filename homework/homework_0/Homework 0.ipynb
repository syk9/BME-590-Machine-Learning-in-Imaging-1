# %% [markdown]
# # Introduction
#
# Demonstrate your skill of markdown
# **[markdown cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)**
# *italics* ~~im new to this~~
# #### PRAY FOR TRE

# %% [markdown]
# ### About me
#
# My name is **Sophia Kim-Wang**. I'm the mother of two rescue mutts named Elsa and Anna. I'm currently a 2nd year PhD student in the DeFrate Lab and am also pursuing an MD.

# %% [markdown]
# ### My Hobbies Ranked
#
# 1. tennis
# 2. yoga
# 3. entertaining my dogs
# 4. cooking

# %% [markdown]
# ```python
# def fibonacci(n):
#     # pseudo code printing the fibonacci sequence in markdown
#     return
# ```

# %%
# See if it works in python3 (doesn't have to)

# %% [markdown]
# # Link your favorite Youtube video
#
# <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ
# " target="_blank"><img src="http://img.youtube.com/vi/dQw4w9WgXcQ/0.jpg"
# alt="IMAGE ALT TEXT HERE" width="240" height="180" border="10" /></a>
